# %%
# !pip install ipywidgets
# !pip install ydata-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting comm>=0.1.3 (from ipywidgets)
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting ipython>=6.1.0 (from ipywidgets)
#   Downloading ipython-8.28.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting traitlets>=4.3.1 (from ipywidgets)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Collecting decorator (from ipython>=6.1.0->ipywidgets)
#   Using cached decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting matplotlib-inline (from ipython>=6.1.0->ipywidgets)
#   Downloading matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting prompt-toolkit<3.1.0,>=3.0.41 (from ipython>=6.1.0->ipywidgets)
#   Downloading prompt_toolkit-3.0.48-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pygments>=2.4.0 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets) (2.11.2)
# Collecting stack-data (from ipython>=6.1.0->ipywidgets)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting exceptiongroup (from ipython>=6.1.0->ipywidgets)
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.6 in /home/newuser/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Collecting pexpect>4.3 (from ipython>=6.1.0->ipywidgets)
#   Using cached pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting parso<0.9.0,>=0.8.3 (from jedi>=0.16->ipython>=6.1.0->ipywidgets)
#   Downloading parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython>=6.1.0->ipywidgets)
#   Using cached ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: wcwidth in /home/newuser/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Collecting executing>=1.2.0 (from stack-data->ipython>=6.1.0->ipywidgets)
#   Downloading executing-2.1.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython>=6.1.0->ipywidgets)
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting pure-eval (from stack-data->ipython>=6.1.0->ipywidgets)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading ipython-8.28.0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 3.8 MB/s eta 0:00:00a 0:00:01
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 4.0 MB/s eta 0:00:00a 0:00:01
# Using cached pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Downloading prompt_toolkit-3.0.48-py3-none-any.whl (386 kB)
# Using cached decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Downloading matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Downloading executing-2.1.0-py2.py3-none-any.whl (25 kB)
# Downloading parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Using cached ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Installing collected packages: pure-eval, ptyprocess, widgetsnbextension, traitlets, prompt-toolkit, pexpect, parso, jupyterlab-widgets, executing, exceptiongroup, decorator, asttokens, stack-data, matplotlib-inline, jedi, comm, ipython, ipywidgets
# Successfully installed asttokens-2.4.1 comm-0.2.2 decorator-5.1.1 exceptiongroup-1.2.2 executing-2.1.0 ipython-8.28.0 ipywidgets-8.1.5 jedi-0.19.1 jupyterlab-widgets-3.0.13 matplotlib-inline-0.1.7 parso-0.8.4 pexpect-4.9.0 prompt-toolkit-3.0.48 ptyprocess-0.7.0 pure-eval-0.2.3 stack-data-0.6.3 traitlets-5.14.3 widgetsnbextension-4.0.13
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ydata-profiling in /home/newuser/.local/lib/python3.10/site-packages (4.11.0)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (2.2.3)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (3.9.2)
# Requirement already satisfied: pydantic>=2 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (2.9.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/lib/python3/dist-packages (from ydata-profiling) (5.4.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (3.1.4)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in /home/newuser/.local/lib/python3.10/site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (0.7.6)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (2.0.2)
# Requirement already satisfied: htmlmin==0.1.12 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (4.66.5)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (1.4)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (0.14.4)
# Requirement already satisfied: typeguard<5,>=3 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (4.3.0)
# Requirement already satisfied: imagehash==4.3.1 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (1.8.1)
# Requirement already satisfied: numba<1,>=0.56.0 in /home/newuser/.local/lib/python3.10/site-packages (from ydata-profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in /home/newuser/.local/lib/python3.10/site-packages (from imagehash==4.3.1->ydata-profiling) (1.7.0)
# Requirement already satisfied: pillow in /home/newuser/.local/lib/python3.10/site-packages (from imagehash==4.3.1->ydata-profiling) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/newuser/.local/lib/python3.10/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/newuser/.local/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/newuser/.local/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/newuser/.local/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/newuser/.local/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/newuser/.local/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/newuser/.local/lib/python3.10/site-packages (from numba<1,>=0.56.0->ydata-profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/newuser/.local/lib/python3.10/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.2)
# Requirement already satisfied: joblib>=0.14.1 in /home/newuser/.local/lib/python3.10/site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/newuser/.local/lib/python3.10/site-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/newuser/.local/lib/python3.10/site-packages (from pydantic>=2->ydata-profiling) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/newuser/.local/lib/python3.10/site-packages (from pydantic>=2->ydata-profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/newuser/.local/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/newuser/.local/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/newuser/.local/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/newuser/.local/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.8.30)
# Requirement already satisfied: patsy>=0.5.6 in /home/newuser/.local/lib/python3.10/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.6)
# Requirement already satisfied: attrs>=19.3.0 in /home/newuser/.local/lib/python3.10/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (24.2.0)
# Requirement already satisfied: networkx>=2.4 in /home/newuser/.local/lib/python3.10/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (3.4.1)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)

# %%
import wandb
import pandas as pd
from ydata_profiling import ProfileReport

# %%
run = wandb.init(
    project="nyc_airbnb",
    group="eda",
    save_code=True,
)
local_path=wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# Finishing last run (ID:6jpe4e82) before initializing another...
#  View run <strong style="color:#cdcd00">golden-water-6</strong> at: <a href='https://wandb.ai/y-khanfir-instadeep/nyc_airbnb/runs/6jpe4e82' target="_blank">https://wandb.ai/y-khanfir-instadeep/nyc_airbnb/runs/6jpe4e82</a><br/> View project at: <a href='https://wandb.ai/y-khanfir-instadeep/nyc_airbnb' target="_blank">https://wandb.ai/y-khanfir-instadeep/nyc_airbnb</a><br/>Synced 4 W&B file(s), 0 media file(s), 14 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241018_144457-6jpe4e82/logs</code>
# Successfully finished last run (ID:6jpe4e82). Initializing new run:<br/>
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/mnt/c/Users/y.khanfir/mlops-training/build-ml-pipeline-for-short-term-rental-prices/src/eda/wandb/run-20241018_150101-0dtpxlfz</code>
# Syncing run <strong><a href='https://wandb.ai/y-khanfir-instadeep/nyc_airbnb/runs/0dtpxlfz' target="_blank">fresh-monkey-7</a></strong> to <a href='https://wandb.ai/y-khanfir-instadeep/nyc_airbnb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/y-khanfir-instadeep/nyc_airbnb' target="_blank">https://wandb.ai/y-khanfir-instadeep/nyc_airbnb</a>
#  View run at <a href='https://wandb.ai/y-khanfir-instadeep/nyc_airbnb/runs/0dtpxlfz' target="_blank">https://wandb.ai/y-khanfir-instadeep/nyc_airbnb/runs/0dtpxlfz</a>

# %%
df.head()
# Out:
#          id                                               name    host_id  \
# 0   9138664                Private Lg Room 15 min to Manhattan   47594947
# 1  31444015  TIME SQUARE CHARMING ONE BED IN HELL'S KITCHEN...    8523790
# 2   8741020  Voted #1 Location Quintessential 1BR W Village...   45854238
# 3  34602077  Spacious 1 bedroom apartment 15min from Manhattan  261055465
# 4  23203149   Big beautiful bedroom in huge Bushwick apartment     143460
#
#   host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0      Iris              Queens       Sunnyside  40.74271  -73.92493
# 1    Johlex           Manhattan  Hell's Kitchen  40.76682  -73.98878
# 2      John           Manhattan    West Village  40.73631  -74.00611
# 3     Regan              Queens         Astoria  40.76424  -73.92351
# 4     Megan            Brooklyn        Bushwick  40.69839  -73.92044
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     74               2                  6  2019-05-26
# 1  Entire home/apt    170               3                  0         NaN
# 2  Entire home/apt    245               3                 51  2018-09-19
# 3  Entire home/apt    125               3                  1  2019-05-24
# 4     Private room     65               2                  8  2019-06-23
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.13                               1                 5
# 1                NaN                               1               188
# 2               1.12                               1                 0
# 3               0.65                               1                13
# 4               0.52                               2                 8

# %%
profile = ProfileReport(df)
profile.to_widgets()
# Out:
# Summarize dataset: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 126/126 [00:19<00:00,  6.41it/s, Completed]
# Generate report structure: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:09<00:00,  9.77s/it]
# Render widgets:   0%|                                                                                                                                            | 0/1 [00:00<?, ?it/s]
#                                 availability_365  \
# availability_365                        1.000000
# calculated_host_listings_count          0.407154
# host_id                                 0.172829
# id                                      0.164731
# latitude                               -0.009651
# longitude                               0.061113
# minimum_nights                          0.081264
# neighbourhood_group                     0.075558
# number_of_reviews                       0.237886
# price                                   0.091799
# reviews_per_month                       0.387509
# room_type                               0.088758
#
#                                 calculated_host_listings_count   host_id  \
# availability_365                                      0.407154  0.172829
# calculated_host_listings_count                        1.000000  0.144830
# host_id                                               0.144830  1.000000
# id                                                    0.133321  0.558145
# latitude                                              0.002377  0.041903
# longitude                                             0.062861  0.106627
# minimum_nights                                        0.063765 -0.138851
# neighbourhood_group                                   0.086084  0.098353
# number_of_reviews                                     0.057464 -0.117507
# price                                                -0.101398 -0.073509
# reviews_per_month                                     0.144355  0.275662
# room_type                                             0.095414  0.092035
#
#                                       id  latitude  longitude  minimum_nights  \
# availability_365                0.164731 -0.009651   0.061113        0.081264
# calculated_host_listings_count  0.133321  0.002377   0.062861        0.063765
# host_id                         0.558145  0.041903   0.106627       -0.138851
# id                              1.000000 -0.001193   0.066518       -0.068274
# latitude                       -0.001193  1.000000   0.040318        0.017124
# longitude                       0.066518  0.040318   1.000000       -0.121498
# minimum_nights                 -0.068274  0.017124  -0.121498        1.000000
# neighbourhood_group             0.059137  0.538339   0.648797        0.000000
# number_of_reviews              -0.302146 -0.038288   0.080778       -0.159285
# price                          -0.026606  0.138701  -0.436764        0.103245
# reviews_per_month               0.368858 -0.027334   0.117056       -0.288277
# room_type                       0.070785  0.111624   0.153825        0.020005
#
#                                 neighbourhood_group  number_of_reviews  \
# availability_365                           0.075558           0.237886
# calculated_host_listings_count             0.086084           0.057464
# host_id                                    0.098353          -0.117507
# id                                         0.059137          -0.302146
# latitude                                   0.538339          -0.038288
# longitude                                  0.648797           0.080778
# minimum_nights                             0.000000          -0.159285
# neighbourhood_group                        1.000000           0.026979
# number_of_reviews                          0.026979           1.000000
# price                                      0.010046          -0.050723
# reviews_per_month                          0.065914           0.701699
# room_type                                  0.124914           0.000000
#
#                                    price  reviews_per_month  room_type
# availability_365                0.091799           0.387509   0.088758
# calculated_host_listings_count -0.101398           0.144355   0.095414
# host_id                        -0.073509           0.275662   0.092035
# id                             -0.026606           0.368858   0.070785
# latitude                        0.138701          -0.027334   0.111624
# longitude                      -0.436764           0.117056   0.153825
# minimum_nights                  0.103245          -0.288277   0.020005
# neighbourhood_group             0.010046           0.065914   0.124914
# number_of_reviews              -0.050723           0.701699   0.000000
# price                           1.000000          -0.018707   0.022859
# reviews_per_month              -0.018707           1.000000   0.017332
# room_type                       0.022859           0.017332   1.000000
#          id                                               name    host_id  \
# 0   9138664                Private Lg Room 15 min to Manhattan   47594947
# 1  31444015  TIME SQUARE CHARMING ONE BED IN HELL'S KITCHEN...    8523790
# 2   8741020  Voted #1 Location Quintessential 1BR W Village...   45854238
# 3  34602077  Spacious 1 bedroom apartment 15min from Manhattan  261055465
# 4  23203149   Big beautiful bedroom in huge Bushwick apartment     143460
# 5   4402805         LRG 2br BKLYN APT CLOSE TO TRAINS AND PARK   22807362
# 6  30070126  ✩Prime Renovated 1/1 Apartment in Upper East S...    4968673
# 7  34231172      Fully renovated brick house floor in Brooklyn   59642348
# 8   5856760         Renovated 1BR in exciting, convenient area   29408349
# 9   7929441                 Beautiful Loft w/ Waterfront View!    1453898
#
#   host_name neighbourhood_group              neighbourhood  latitude  \
# 0      Iris              Queens                  Sunnyside  40.74271
# 1    Johlex           Manhattan             Hell's Kitchen  40.76682
# 2      John           Manhattan               West Village  40.73631
# 3     Regan              Queens                    Astoria  40.76424
# 4     Megan            Brooklyn                   Bushwick  40.69839
# 5     Jenny            Brooklyn  Prospect-Lefferts Gardens  40.66025
# 6      Sean           Manhattan            Upper East Side  40.76831
# 7     Kevin            Brooklyn                Sunset Park  40.64550
# 8      Chad           Manhattan                  Chinatown  40.71490
# 9   Anthony            Brooklyn               Williamsburg  40.71268
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -73.92493     Private room     74               2                  6
# 1  -73.98878  Entire home/apt    170               3                  0
# 2  -74.00611  Entire home/apt    245               3                 51
# 3  -73.92351  Entire home/apt    125               3                  1
# 4  -73.92044     Private room     65               2                  8
# 5  -73.96270  Entire home/apt    120               3                  3
# 6  -73.95929  Entire home/apt    200               5                  2
# 7  -74.01262  Entire home/apt     95               1                  9
# 8  -73.99976  Entire home/apt    179               5                  7
# 9  -73.96676     Private room    105               2                232
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2019-05-26               0.13                               1
# 1         NaN                NaN                               1
# 2  2018-09-19               1.12                               1
# 3  2019-05-24               0.65                               1
# 4  2019-06-23               0.52                               2
# 5  2018-08-28               0.05                               1
# 6  2019-05-26               0.68                               1
# 7  2019-07-08               9.00                               1
# 8  2017-04-18               0.14                               1
# 9  2019-06-19               5.00                               3
#
#    availability_365
# 0                 5
# 1               188
# 2                 0
# 3                13
# 4                 8
# 5                16
# 6                71
# 7               106
# 8                 0
# 9                64
#              id                                               name    host_id  \
# 19990   5192459                   Quiet Room in 4BR UWS Brownstone   10677483
# 19991   1327940                 Huge Gorgeous Park View Apartment!    3290436
# 19992  23612681   Shared Room 1 Stop from Manhattan on the F Train   55724558
# 19993  34485745           Midtown Manhattan Stunner - Private room  261632622
# 19994  25616250  Stylish, spacious, private 1BR apt in Ditmas Park  125396920
# 19995   7094539                  Tranquil haven in bubbly Brooklyn    2052211
# 19996   4424261                    Large 1 BR with backyard on UWS    3447311
# 19997   4545882                Amazing studio/Loft with a backyard   23569951
# 19998  26518547          U2 comfortable double bed sleeps 2 guests     295128
# 19999  33631782               Private Bedroom in Williamsburg Apt!    8569221
#
#           host_name neighbourhood_group     neighbourhood  latitude  \
# 19990          Greg           Manhattan   Upper West Side  40.80173
# 19991         Hadar            Brooklyn          Flatbush  40.65335
# 19992        Taylor              Queens  Long Island City  40.76006
# 19993      Royalton           Manhattan  Theater District  40.75491
# 19994          Adam            Brooklyn          Flatbush  40.64314
# 19995       Adriana            Brooklyn   Windsor Terrace  40.65360
# 19996         Sarah           Manhattan   Upper West Side  40.80188
# 19997         Kaveh           Manhattan   Upper East Side  40.78110
# 19998  Carol Gloria               Bronx      Clason Point  40.81225
# 19999          Andi            Brooklyn      Williamsburg  40.71829
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 19990  -73.96625     Private room     70               1                  0
# 19991  -73.96257  Entire home/apt    120               3                 13
# 19992  -73.94080     Private room     55               4                  2
# 19993  -73.98507     Private room    100               1                  3
# 19994  -73.95705  Entire home/apt     75               3                 10
# 19995  -73.97546  Entire home/apt    143              14                  2
# 19996  -73.96808  Entire home/apt    200               2                 22
# 19997  -73.94567  Entire home/apt    220               3                 28
# 19998  -73.85502     Private room     80               1                  4
# 19999  -73.95819     Private room    109               3                  3
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 19990         NaN                NaN                               1
# 19991  2016-08-27               0.28                               2
# 19992  2019-06-01               0.65                               5
# 19993  2019-06-16               3.00                               9
# 19994  2019-01-03               0.84                               1
# 19995  2016-08-27               0.04                               1
# 19996  2019-05-21               0.50                               1
# 19997  2019-05-23               0.50                               1
# 19998  2019-07-01               1.48                               7
# 19999  2019-04-28               1.07                               2
#
#        availability_365
# 19990                 0
# 19991               327
# 19992                89
# 19993               318
# 19994                 0
# 19995                10
# 19996                 0
# 19997               293
# 19998               365
# 19999                97
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()
# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19001 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19001 non-null  int64
#  1   name                            18994 non-null  object
#  2   host_id                         19001 non-null  int64
#  3   host_name                       18993 non-null  object
#  4   neighbourhood_group             19001 non-null  object
#  5   neighbourhood                   19001 non-null  object
#  6   latitude                        19001 non-null  float64
#  7   longitude                       19001 non-null  float64
#  8   room_type                       19001 non-null  object
#  9   price                           19001 non-null  int64
#  10  minimum_nights                  19001 non-null  int64
#  11  number_of_reviews               19001 non-null  int64
#  12  last_review                     15243 non-null  datetime64[ns]
#  13  reviews_per_month               15243 non-null  float64
#  14  calculated_host_listings_count  19001 non-null  int64
#  15  availability_365                19001 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 2.5+ MB

# %%
run.finish()
# Out:
#  View run <strong style="color:#cdcd00">fresh-monkey-7</strong> at: <a href='https://wandb.ai/y-khanfir-instadeep/nyc_airbnb/runs/0dtpxlfz' target="_blank">https://wandb.ai/y-khanfir-instadeep/nyc_airbnb/runs/0dtpxlfz</a><br/> View project at: <a href='https://wandb.ai/y-khanfir-instadeep/nyc_airbnb' target="_blank">https://wandb.ai/y-khanfir-instadeep/nyc_airbnb</a><br/>Synced 4 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241018_150101-0dtpxlfz/logs</code>
